# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
path="C:\\Users\\basva\\Downloads\\Telecommunication"
df=pd.read_csv(path)     # importing Data
df.head(6)
# Out:
#    Unnamed: 0  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0           0  7590-VHVEG  Female              0     Yes         No       1
# 1           1  5575-GNVDE    Male              0      No         No      34
# 2           2  3668-QPYBK    Male              0      No         No       2
# 3           3  7795-CFOCW    Male              0      No         No      45
# 4           4  9237-HQITU  Female              0      No         No       2
# 5           5  9305-CDSKC  Female              0      No         No       8
#
#   PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# 0           No  No phone service             DSL  ...               No
# 1          Yes                No             DSL  ...              Yes
# 2          Yes                No             DSL  ...               No
# 3           No  No phone service             DSL  ...              Yes
# 4          Yes                No     Fiber optic  ...               No
# 5          Yes               Yes     Fiber optic  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
# 5          No         Yes             Yes  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges  Churn
# 0           Electronic check          29.85        29.85     No
# 1               Mailed check          56.95      1889.50     No
# 2               Mailed check          53.85       108.15    Yes
# 3  Bank transfer (automatic)          42.30      1840.75     No
# 4           Electronic check          70.70       151.65    Yes
# 5           Electronic check          99.65       820.50    Yes
#
# [6 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'customerID', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0', axis=1)
df = df.drop('customerID', axis=1)
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
# Type of Dataset
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#shape of Dataset
df.shape
# Out:
# (7032, 20)

# %%
# columns in Dataset
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Information about Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
#  16  PaymentMethod     7032 non-null   object
#  17  MonthlyCharges    7032 non-null   float64
#  18  TotalCharges      7032 non-null   float64
#  19  Churn             7032 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.1+ MB

# %%
#checking null values in Dataset
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.2

# %% [markdown]
# ### Input-'customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
# ###      'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
# ###      'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
# ###      'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
# ###      'PaymentMethod', 'MonthlyCharges', 'TotalCharges'

# %% [markdown]
# ## Target-"Churn"
# ## Alg-classification task
# ## Evaluation- Accuracy
# ## Split the dataset into Training and Testing (recommended 75:25 split).

# %%
y=df['Churn']
X=df[[ 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges' 
      ]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.75,random_state=100)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (5274, 19) (5274,)
# (1758, 19) (1758,)

# %%
X_train.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 5514  Female              0     Yes         No       7          Yes
# 1671  Female              0      No         No       4          Yes
# 510     Male              0      No         No      61          Yes
# 1590    Male              1      No         No       2          Yes
# 3324  Female              0     Yes         No      18          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 5514            No     Fiber optic             No           No
# 1671           Yes     Fiber optic            Yes           No
# 510            Yes     Fiber optic            Yes           No
# 1590            No     Fiber optic             No          Yes
# 3324            No             DSL             No           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 5514               No          No          No              No  Month-to-month
# 1671               No          No          No              No  Month-to-month
# 510               Yes          No         Yes             Yes  Month-to-month
# 1590               No          No          No              No  Month-to-month
# 3324               No         Yes          No              No  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges
# 5514              Yes  Bank transfer (automatic)           69.20        477.55
# 1671              Yes           Electronic check           80.15        319.85
# 510               Yes           Electronic check          106.45       6300.15
# 1590              Yes           Electronic check           74.70        165.40
# 3324              Yes               Mailed check           50.30        908.75

# %%
X_train_cat=X_train.select_dtypes(include=['object'])
X_train_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 5514  Female     Yes         No          Yes            No     Fiber optic
# 1671  Female      No         No          Yes           Yes     Fiber optic
# 510     Male      No         No          Yes           Yes     Fiber optic
# 1590    Male      No         No          Yes            No     Fiber optic
# 3324  Female     Yes         No          Yes            No             DSL
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 5514             No           No               No          No          No
# 1671            Yes           No               No          No          No
# 510             Yes           No              Yes          No         Yes
# 1590             No          Yes               No          No          No
# 3324             No           No               No         Yes          No
#
#      StreamingMovies        Contract PaperlessBilling  \
# 5514              No  Month-to-month              Yes
# 1671              No  Month-to-month              Yes
# 510              Yes  Month-to-month              Yes
# 1590              No  Month-to-month              Yes
# 3324              No  Month-to-month              Yes
#
#                   PaymentMethod
# 5514  Bank transfer (automatic)
# 1671           Electronic check
# 510            Electronic check
# 1590           Electronic check
# 3324               Mailed check

# %%
X_train_num=X_train.select_dtypes(include=['int64','float64'])
X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 5514              0       7           69.20        477.55
# 1671              0       4           80.15        319.85
# 510               0      61          106.45       6300.15
# 1590              1       2           74.70        165.40
# 3324              0      18           50.30        908.75

# %% [markdown]
# # Data preparation on train data:

# %%
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
x_train_num_rescaled=pd.DataFrame(Scaler.fit_transform(X_train_num),
                                 columns=X_train_num.columns,
                                 index=X_train_num.index)
x_train_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 5514      -0.438945 -1.035648        0.151080     -0.795902
# 1671      -0.438945 -1.157923        0.514997     -0.865409
# 510       -0.438945  1.165295        1.389062      1.770434
# 1590       2.278188 -1.239439        0.333869     -0.933484
# 3324      -0.438945 -0.587308       -0.477051     -0.605849

# %%
X_train_num.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    5274.000000  5274.000000     5274.000000   5274.000000
# mean        0.161547    32.409556       64.654124   2283.323341
# std         0.368070    24.537263       30.092133   2269.052626
# min         0.000000     1.000000       18.250000     18.850000
# 25%         0.000000     9.000000       35.500000    395.725000
# 50%         0.000000    29.000000       70.250000   1394.325000
# 75%         0.000000    55.000000       89.850000   3778.075000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
X_train_cat['gender'].value_counts(normalize=True)
# Out:
# Male      0.505878
# Female    0.494122
# Name: gender, dtype: float64

# %%
X_train_cat['Partner'].value_counts(normalize=True)
# Out:
# No     0.521426
# Yes    0.478574
# Name: Partner, dtype: float64

# %%
X_train_cat['Dependents'].value_counts(normalize=True)
# Out:
# No     0.703641
# Yes    0.296359
# Name: Dependents, dtype: float64

# %%
X_train_cat['PhoneService'].value_counts(normalize=True)
# Out:
# Yes    0.904816
# No     0.095184
# Name: PhoneService, dtype: float64

# %%
X_train_cat['MultipleLines'].value_counts(normalize=True)
# Out:
# No                  0.487865
# Yes                 0.416951
# No phone service    0.095184
# Name: MultipleLines, dtype: float64

# %%
X_train_cat['InternetService'].value_counts(normalize=True)
# Out:
# Fiber optic    0.437239
# DSL            0.343572
# No             0.219188
# Name: InternetService, dtype: float64

# %%
X_train_cat['OnlineSecurity'].value_counts(normalize=True)
# Out:
# No                     0.496397
# Yes                    0.284414
# No internet service    0.219188
# Name: OnlineSecurity, dtype: float64

# %%
X_train_cat['OnlineBackup'].value_counts(normalize=True)
# Out:
# No                     0.432878
# Yes                    0.347933
# No internet service    0.219188
# Name: OnlineBackup, dtype: float64

# %%
X_train_cat['DeviceProtection'].value_counts(normalize=True)
# Out:
# No                     0.437050
# Yes                    0.343762
# No internet service    0.219188
# Name: DeviceProtection, dtype: float64

# %%
X_train_cat['TechSupport'].value_counts(normalize=True)
# Out:
# No                     0.485021
# Yes                    0.295791
# No internet service    0.219188
# Name: TechSupport, dtype: float64

# %%
X_train_cat['StreamingTV'].value_counts(normalize=True)
# Out:
# No                     0.399697
# Yes                    0.381115
# No internet service    0.219188
# Name: StreamingTV, dtype: float64

# %%
X_train_cat['StreamingMovies'].value_counts(normalize=True)
# Out:
# No                     0.393250
# Yes                    0.387562
# No internet service    0.219188
# Name: StreamingMovies, dtype: float64

# %%
X_train_cat['Contract'].value_counts(normalize=True)
# Out:
# Month-to-month    0.547402
# Two year          0.237770
# One year          0.214827
# Name: Contract, dtype: float64

# %%
X_train_cat['PaperlessBilling'].value_counts(normalize=True)
# Out:
# Yes    0.588358
# No     0.411642
# Name: PaperlessBilling, dtype: float64

# %%
X_train_cat['PaymentMethod'].value_counts(normalize=True)
# Out:
# Electronic check             0.331437
# Mailed check                 0.232461
# Credit card (automatic)      0.218809
# Bank transfer (automatic)    0.217292
# Name: PaymentMethod, dtype: float64

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder( drop='first',sparse=False)

X_train_cat_ohe = pd.DataFrame(encoder.fit_transform(X_train_cat), 
                               columns=encoder.get_feature_names_out(X_train_cat.columns), 
                               index = X_train_cat.index)

X_train_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 5514          0.0          1.0             0.0               1.0
# 1671          0.0          0.0             0.0               1.0
# 510           1.0          0.0             0.0               1.0
# 1590          1.0          0.0             0.0               1.0
# 3324          0.0          1.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 5514                             0.0                0.0
# 1671                             0.0                1.0
# 510                              0.0                1.0
# 1590                             0.0                0.0
# 3324                             0.0                0.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 5514                          1.0                 0.0
# 1671                          1.0                 0.0
# 510                           1.0                 0.0
# 1590                          1.0                 0.0
# 3324                          0.0                 0.0
#
#       OnlineSecurity_No internet service  OnlineSecurity_Yes  ...  \
# 5514                                 0.0                 0.0  ...
# 1671                                 0.0                 1.0  ...
# 510                                  0.0                 1.0  ...
# 1590                                 0.0                 0.0  ...
# 3324                                 0.0                 0.0  ...
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 5514                              0.0              0.0
# 1671                              0.0              0.0
# 510                               0.0              1.0
# 1590                              0.0              0.0
# 3324                              0.0              0.0
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 5514                                  0.0                  0.0
# 1671                                  0.0                  0.0
# 510                                   0.0                  1.0
# 1590                                  0.0                  0.0
# 3324                                  0.0                  0.0
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 5514                0.0                0.0                   1.0
# 1671                0.0                0.0                   1.0
# 510                 0.0                0.0                   1.0
# 1590                0.0                0.0                   1.0
# 3324                0.0                0.0                   1.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5514                                    0.0                             0.0
# 1671                                    0.0                             1.0
# 510                                     0.0                             1.0
# 1590                                    0.0                             1.0
# 3324                                    0.0                             0.0
#
#       PaymentMethod_Mailed check
# 5514                         0.0
# 1671                         0.0
# 510                          0.0
# 1590                         0.0
# 3324                         1.0
#
# [5 rows x 26 columns]

# %%
encoder.categories_
# Out:
# [array(['Female', 'Male'], dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['No', 'No phone service', 'Yes'], dtype=object),
#  array(['DSL', 'Fiber optic', 'No'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['Month-to-month', 'One year', 'Two year'], dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['Bank transfer (automatic)', 'Credit card (automatic)',
#         'Electronic check', 'Mailed check'], dtype=object)]

# %%
X_train_transformed=pd.concat([x_train_num_rescaled,X_train_cat_ohe],axis=1)
X_train_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 5514      -0.438945 -1.035648        0.151080     -0.795902          0.0
# 1671      -0.438945 -1.157923        0.514997     -0.865409          0.0
# 510       -0.438945  1.165295        1.389062      1.770434          1.0
# 1590       2.278188 -1.239439        0.333869     -0.933484          1.0
# 3324      -0.438945 -0.587308       -0.477051     -0.605849          0.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 5514          1.0             0.0               1.0
# 1671          0.0             0.0               1.0
# 510           0.0             0.0               1.0
# 1590          0.0             0.0               1.0
# 3324          1.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 5514                             0.0                0.0  ...
# 1671                             0.0                1.0  ...
# 510                              0.0                1.0  ...
# 1590                             0.0                0.0  ...
# 3324                             0.0                0.0  ...
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 5514                              0.0              0.0
# 1671                              0.0              0.0
# 510                               0.0              1.0
# 1590                              0.0              0.0
# 3324                              0.0              0.0
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 5514                                  0.0                  0.0
# 1671                                  0.0                  0.0
# 510                                   0.0                  1.0
# 1590                                  0.0                  0.0
# 3324                                  0.0                  0.0
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 5514                0.0                0.0                   1.0
# 1671                0.0                0.0                   1.0
# 510                 0.0                0.0                   1.0
# 1590                0.0                0.0                   1.0
# 3324                0.0                0.0                   1.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5514                                    0.0                             0.0
# 1671                                    0.0                             1.0
# 510                                     0.0                             1.0
# 1590                                    0.0                             1.0
# 3324                                    0.0                             0.0
#
#       PaymentMethod_Mailed check
# 5514                         0.0
# 1671                         0.0
# 510                          0.0
# 1590                         0.0
# 3324                         1.0
#
# [5 rows x 30 columns]

# %% [markdown]
# # Data preparation on test data:

# %%
X_test_num=X_test.select_dtypes(include=['int64','float64'])
X_test_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 939               0      24           79.85       2001.00
# 3724              0      57          104.50       5921.35
# 1756              0      58           24.45       1513.60
# 2278              0       1           71.55         71.55
# 1867              0      41           19.70        804.25

# %%
x_test_num_rescaled=pd.DataFrame(Scaler.transform(X_test_num),
                                 columns=X_test_num.columns,
                                 index=X_test_num.index)
x_test_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 939       -0.438945 -0.342758        0.505026     -0.124435
# 3724      -0.438945  1.002262        1.324255      1.603476
# 1756      -0.438945  1.043021       -1.336161     -0.339259
# 2278      -0.438945 -1.280197        0.229180     -0.974849
# 1867      -0.438945  0.350131       -1.494025     -0.651908

# %%
X_test_cat=X_test.select_dtypes(include=['object'])
X_test_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 939     Male      No         No          Yes            No     Fiber optic
# 3724  Female     Yes         No          Yes           Yes     Fiber optic
# 1756    Male      No         No          Yes           Yes              No
# 2278    Male      No         No          Yes            No     Fiber optic
# 1867  Female     Yes        Yes          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 939                    No                   No                   No
# 3724                   No                  Yes                  Yes
# 1756  No internet service  No internet service  No internet service
# 2278                   No                   No                   No
# 1867  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# 939                    No                   No                  Yes
# 3724                   No                  Yes                  Yes
# 1756  No internet service  No internet service  No internet service
# 2278                   No                   No                   No
# 1867  No internet service  No internet service  No internet service
#
#             Contract PaperlessBilling              PaymentMethod
# 939   Month-to-month              Yes    Credit card (automatic)
# 3724  Month-to-month              Yes    Credit card (automatic)
# 1756        Two year              Yes    Credit card (automatic)
# 2278  Month-to-month              Yes               Mailed check
# 1867        Two year               No  Bank transfer (automatic)

# %%
X_test_cat_le = pd.DataFrame(encoder.transform(X_test_cat), 
                               columns=encoder.get_feature_names_out(X_test_cat.columns), 
                               index = X_test_cat.index)

X_test_cat_le.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 939           1.0          0.0             0.0               1.0
# 3724          0.0          1.0             0.0               1.0
# 1756          1.0          0.0             0.0               1.0
# 2278          1.0          0.0             0.0               1.0
# 1867          0.0          1.0             1.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 939                              0.0                0.0
# 3724                             0.0                1.0
# 1756                             0.0                1.0
# 2278                             0.0                0.0
# 1867                             0.0                0.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 939                           1.0                 0.0
# 3724                          1.0                 0.0
# 1756                          0.0                 1.0
# 2278                          1.0                 0.0
# 1867                          0.0                 1.0
#
#       OnlineSecurity_No internet service  OnlineSecurity_Yes  ...  \
# 939                                  0.0                 0.0  ...
# 3724                                 0.0                 0.0  ...
# 1756                                 1.0                 0.0  ...
# 2278                                 0.0                 0.0  ...
# 1867                                 1.0                 0.0  ...
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 939                               0.0              0.0
# 3724                              0.0              1.0
# 1756                              1.0              0.0
# 2278                              0.0              0.0
# 1867                              1.0              0.0
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 939                                   0.0                  1.0
# 3724                                  0.0                  1.0
# 1756                                  1.0                  0.0
# 2278                                  0.0                  0.0
# 1867                                  1.0                  0.0
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 939                 0.0                0.0                   1.0
# 3724                0.0                0.0                   1.0
# 1756                0.0                1.0                   1.0
# 2278                0.0                0.0                   1.0
# 1867                0.0                1.0                   0.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 939                                     1.0                             0.0
# 3724                                    1.0                             0.0
# 1756                                    1.0                             0.0
# 2278                                    0.0                             0.0
# 1867                                    0.0                             0.0
#
#       PaymentMethod_Mailed check
# 939                          0.0
# 3724                         0.0
# 1756                         0.0
# 2278                         1.0
# 1867                         0.0
#
# [5 rows x 26 columns]

# %%
X_test_transformed=pd.concat([x_test_num_rescaled,X_test_cat_le],axis=1)
X_test_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 939       -0.438945 -0.342758        0.505026     -0.124435          1.0
# 3724      -0.438945  1.002262        1.324255      1.603476          0.0
# 1756      -0.438945  1.043021       -1.336161     -0.339259          1.0
# 2278      -0.438945 -1.280197        0.229180     -0.974849          1.0
# 1867      -0.438945  0.350131       -1.494025     -0.651908          0.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 939           0.0             0.0               1.0
# 3724          1.0             0.0               1.0
# 1756          0.0             0.0               1.0
# 2278          0.0             0.0               1.0
# 1867          1.0             1.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 939                              0.0                0.0  ...
# 3724                             0.0                1.0  ...
# 1756                             0.0                1.0  ...
# 2278                             0.0                0.0  ...
# 1867                             0.0                0.0  ...
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 939                               0.0              0.0
# 3724                              0.0              1.0
# 1756                              1.0              0.0
# 2278                              0.0              0.0
# 1867                              1.0              0.0
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 939                                   0.0                  1.0
# 3724                                  0.0                  1.0
# 1756                                  1.0                  0.0
# 2278                                  0.0                  0.0
# 1867                                  1.0                  0.0
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 939                 0.0                0.0                   1.0
# 3724                0.0                0.0                   1.0
# 1756                0.0                1.0                   1.0
# 2278                0.0                0.0                   1.0
# 1867                0.0                1.0                   0.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 939                                     1.0                             0.0
# 3724                                    1.0                             0.0
# 1756                                    1.0                             0.0
# 2278                                    0.0                             0.0
# 1867                                    0.0                             0.0
#
#       PaymentMethod_Mailed check
# 939                          0.0
# 3724                         0.0
# 1756                         0.0
# 2278                         1.0
# 1867                         0.0
#
# [5 rows x 30 columns]

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_transformed, y_train)
# Out:
# LogisticRegression()

# %%
y_test_pred = classifier.predict(X_test_transformed)

# %%
from sklearn import metrics

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7957906712172924

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.757679180887372

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7252559726962458

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7821387940841866

# %% [markdown]
# # Support Vector Machines

# %%
from sklearn.svm import SVC
classifier=SVC()
classifier.fit(X_train_transformed, y_train)
y_test_pred = classifier.predict(X_test_transformed)
metrics.accuracy_score(y_test, y_test_pred)n
# Out:
# 0.78839590443686

# %% [markdown]
# # conclusion:
# * LogisticRegression is the best algorithm for Churn Prediction.
# * when compared to other Classifiers LogisticRegression having more accuracy.
# * accuracy value for LogisticRegression is 0.75.
